# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Task 1 - Fitbit Dataset
#
# 1. Read this dataset in pandas , mysql and mongodb
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
#  ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
# 4 . Find out in this data that how many unique id's we have
# 5 . which id is one of the active id that you have in whole dataset
# 6 . how many of them have not logged there activity find out in terms of number of ids
# 7 . Find out who is the laziest person id that we have in dataset
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset
# 9. how many person are not a regular person with respect to activity try to find out those
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
# 11 . who is the 5th most laziest person avilable in dataset find it out
# 12 . what is a totla acumulative calories burn for a person find out

# %% [markdown]
# #task 2 - Superstore_USA
# 1 . load this data in sql and in pandas with a relation in sql
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3 . Find out how return that we ahve recived and with a product id
# 4 . try  to join order and return data both in sql and pandas
# 5 . Try to find out how many unique customer that we have
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11 . Gorup by region and find out which region is more profitable
# 12 . Try to find out overalll in which country we are giving more didscount
# 13 . Give me a list of unique postal code
# 14 . which customer segement is more profitalble find it out .
# 15 . try to find out the 10th most loss making product catagory .
# 16 . Try to find out 10 top  product with highest margins
#
# submit your git link for the same
#
# you have to submit this task by next Friday 5th 11PM IST  to respective mail id
# sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %%
df = pd.read_csv("Superstore_USAOrders.csv")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101  5/28/2012
# 1        West        Washington   Anacortes        98221   7/7/2010
# 2        West        Washington   Anacortes        98221  7/27/2011
# 3        West        Washington   Anacortes        98221  7/27/2011
# 4        West        Washington   Anacortes        98221  7/27/2011
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314  5/14/2013
# 9422     East     West Virginia  Charleston        25314  5/14/2013
# 9423     East     West Virginia  Charleston        25314  9/12/2013
# 9424     West           Wyoming    Cheyenne        82001   2/8/2010
# 9425     West           Wyoming    Cheyenne        82001  9/12/2013
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0     5/30/2012     1.320000                     2     5.90    88525
# 1      7/8/2010     4.560000                     4    13.01    88522
# 2     7/28/2011   -47.640000                     7    49.92    88523
# 3     7/28/2011   -30.510000                     7    41.64    88523
# 4     7/27/2011   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421  5/15/2013   137.860000                    13   447.87    87532
# 9422  5/14/2013   -39.070000                     3    13.23    87532
# 9423  9/14/2013 -1225.029097                     4  2215.93    87533
# 9424  2/11/2010   349.485000                     5   506.50    87530
# 9425  9/14/2013    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
df2 = pd.read_excel("Superstore_USA (2).xlsx",sheet_name=1)

# %%
df2
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df3 = pd.read_excel("Superstore_USA (2).xlsx",sheet_name=2)

# %%
df3
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df['Order ID'].unique()
# Out:
# array([88525, 88522, 88523, ..., 87532, 87533, 87530], dtype=int64)

# %%
#how many return we have recieved with prtduct id
k = pd.DataFrame(df['Order ID'],['Product Name'])
l = pd.DataFrame(df2['Order ID'])
pd.merge(k,l)
# Out:
# Empty DataFrame
# Columns: [Order ID]
# Index: []

# %%
#try to join order and return data both in sql and 
pd.merge(df,df2,how='inner')
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0   Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1            Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2            Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3            Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4          Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
# ..                   ...          ...              ...              ...  ...
# 93         Gordon Brandt  Regular Air        Corporate  Office Supplies  ...
# 94         Gordon Brandt  Regular Air        Corporate  Office Supplies  ...
# 95         Gordon Brandt  Express Air        Corporate  Office Supplies  ...
# 96         Andrew Levine  Regular Air         Consumer       Technology  ...
# 97          Peter Brooks  Regular Air   Small Business        Furniture  ...
#
#    State or Province           City Postal Code  Order Date  Ship Date  \
# 0           New York  New York City       10012   4/20/2011  4/24/2011
# 1         Washington        Seattle       98103    4/4/2010   4/6/2010
# 2         Washington        Seattle       98103    4/4/2010   4/6/2010
# 3         Washington        Seattle       98103   8/16/2013  8/18/2013
# 4     North Carolina      Charlotte       28204   8/12/2013  8/12/2013
# ..               ...            ...         ...         ...        ...
# 93        California    Los Angeles       90061    1/4/2013   1/6/2013
# 94        California    Los Angeles       90061    1/4/2013   1/5/2013
# 95        California    Los Angeles       90061   6/25/2013  6/27/2013
# 96      Pennsylvania   Philadelphia       19112   9/30/2012  10/2/2012
# 97          New York  New York City       10112   9/11/2012  9/13/2012
#
#        Profit Quantity ordered new     Sales Order ID    Status
# 0     -6.8200                    9     54.79     9895  Returned
# 1    112.0600                   47    228.46    13959  Returned
# 2     16.7900                   19     77.61    13959  Returned
# 3    -89.0600                   52    190.52    36038  Returned
# 4    -81.9413                   76    912.06    39490  Returned
# ..        ...                  ...       ...      ...       ...
# 93   -33.9680                    3    113.14     7107  Returned
# 94   163.1200                   35   1886.52     7107  Returned
# 95   -22.5600                   12     73.71    42823  Returned
# 96   165.2000                   96   1337.67    13638  Returned
# 97  1844.9600                   92  12002.16    47109  Returned
#
# [98 rows x 25 columns]

# %%
#Try to find out how many unique customer that we have
df['Customer Name'].unique()
# Out:
# array(['Janice Fletcher', 'Bonnie Potter', 'Ronnie Proctor', ...,
#        'Florence Gold', 'Frederick Cole', 'Tammy Buckley'], dtype=object)

# %%
#try to find out in how many regions we are selling a product and who is a manager for a respective region 
m = pd.DataFrame(df[["Region","Product Name"]])
n = pd.DataFrame(df3[["Region","Manager"]])
pd.merge(m,n,on="Region")
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %%
#find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
df['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
a=0
for i in df['Ship Mode']:
    if(i == "Regular Air"):
        a= a+1
print(a)
# Out:
# 7036

# %%
b=0
for i in df['Ship Mode']:
    if(i == "Express Air"):
        b= b+1
print(b)
# Out:
# 1107

# %%
c=0
for i in df['Ship Mode']:
    if(i == "Delivery Truck"):
        c= c+1
print(c)
# Out:
# 1283

# %%
# Create a new coulmn and try to find our a diffrence between order date and shipment date
df.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity ordered new      int64
# Sales                   float64
# Order ID                  int64
# dtype: object

# %%
df['Order Date'] = df['Order Date'].astype('datetime64')

# %%
df['Ship Date'] = df['Ship Date'].astype('datetime64')

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales Order ID
# 0    1.3200                     2     5.90    88525
# 1    4.5600                     4    13.01    88522
# 2  -47.6400                     7    49.92    88523
# 3  -30.5100                     7    41.64    88523
# 4  998.2023                     8  1446.67    88523
#
# [5 rows x 24 columns]

# %%
df['DaysTaken'] = df['Ship Date'] - df['Order Date']

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30    1.3200
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08    4.5600
# 2        Washington  Anacortes       98221  2011-07-27 2011-07-28  -47.6400
# 3        Washington  Anacortes       98221  2011-07-27 2011-07-28  -30.5100
# 4        Washington  Anacortes       98221  2011-07-27 2011-07-27  998.2023
#
#   Quantity ordered new    Sales Order ID DaysTaken
# 0                    2     5.90    88525    2 days
# 1                    4    13.01    88522    1 days
# 2                    7    49.92    88523    1 days
# 3                    7    41.64    88523    1 days
# 4                    8  1446.67    88523    0 days
#
# [5 rows x 25 columns]

# %%
df['DaysTaken'] = df['DaysTaken'].astype(str)

# %%
df['DaysTaken'] = df['DaysTaken'].str.replace("days","")

# %%
df['DaysTaken'] = df['DaysTaken'].astype(int)

# %%
a=0
for i in df['DaysTaken']:
    if i >= 9 :
        a=a+1
print(a)
# Out:
# 121

# %%
#base on question number 8 find out for which order id we have shipment duration more than 10 days

b=0
for i in df['DaysTaken']:
    if i > 10 :
        b=b+1
print(b)
# Out:
# 23

# %%
# Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
df4 = pd.DataFrame(df[["Order ID","DaysTaken"]])
df5 = pd.DataFrame(df2[["Order ID","Status"]])
df6 = pd.merge(df4,df5)

# %%
df6
# Out:
#     Order ID  DaysTaken    Status
# 0       9895          4  Returned
# 1      13959          2  Returned
# 2      13959          2  Returned
# 3      36038          2  Returned
# 4      39490          0  Returned
# ..       ...        ...       ...
# 93      7107          2  Returned
# 94      7107          1  Returned
# 95     42823          2  Returned
# 96     13638          2  Returned
# 97     47109          2  Returned
#
# [98 rows x 3 columns]

# %%
a=0
for i in df6['DaysTaken']:
    if i >= 15:
        a = a+1

print(a)
# Out:
# 0

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#      State or Province        City Postal Code  Order Date  Ship Date  \
# 0             Illinois     Addison       60101  2012-05-28 2012-05-30
# 1           Washington   Anacortes       98221  2010-07-07 2010-07-08
# 2           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 3           Washington   Anacortes       98221  2011-07-27 2011-07-28
# 4           Washington   Anacortes       98221  2011-07-27 2011-07-27
# ...                ...         ...         ...         ...        ...
# 9421     West Virginia  Charleston       25314  2013-05-14 2013-05-15
# 9422     West Virginia  Charleston       25314  2013-05-14 2013-05-14
# 9423     West Virginia  Charleston       25314  2013-09-12 2013-09-14
# 9424           Wyoming    Cheyenne       82001  2010-02-08 2010-02-11
# 9425           Wyoming    Cheyenne       82001  2013-09-12 2013-09-14
#
#            Profit Quantity ordered new    Sales Order ID DaysTaken
# 0        1.320000                    2     5.90    88525         2
# 1        4.560000                    4    13.01    88522         1
# 2      -47.640000                    7    49.92    88523         1
# 3      -30.510000                    7    41.64    88523         1
# 4      998.202300                    8  1446.67    88523         0
# ...           ...                  ...      ...      ...       ...
# 9421   137.860000                   13   447.87    87532         1
# 9422   -39.070000                    3    13.23    87532         0
# 9423 -1225.029097                    4  2215.93    87533         2
# 9424   349.485000                    5   506.50    87530         3
# 9425    78.062400                   23   172.48    87533         2
#
# [9426 rows x 25 columns]

# %%
#Group by region and find out which region is more profitable
profit = df[["Region","Profit"]].groupby("Region").sum()

# %%
max(profit["Profit"])
# Out:
# 519825.56706600066

# %%
#Try to find out overalll in which country we are giving more didscount 
discount = df[["Discount","State or Province"]].groupby("State or Province").count()

# %%
discount
# Out:
#                       Discount
# State or Province
# Alabama                    125
# Arizona                    134
# Arkansas                   123
# California                1021
# Colorado                   177
# Connecticut                 82
# Delaware                    15
# District of Columbia        68
# Florida                    522
# Georgia                    214
# Idaho                      114
# Illinois                   584
# Indiana                    241
# Iowa                       156
# Kansas                     133
# Kentucky                    83
# Louisiana                   89
# Maine                      128
# Maryland                   178
# Massachusetts              222
# Michigan                   327
# Minnesota                  239
# Mississippi                 78
# Missouri                   161
# Montana                     49
# Nebraska                    77
# Nevada                      43
# New Hampshire               54
# New Jersey                 177
# New Mexico                  84
# New York                   574
# North Carolina             251
# North Dakota                34
# Ohio                       396
# Oklahoma                   104
# Oregon                     168
# Pennsylvania               271
# Rhode Island                20
# South Carolina             105
# South Dakota                28
# Tennessee                  166
# Texas                      646
# Utah                       146
# Vermont                     61
# Virginia                   198
# Washington                 327
# West Virginia               43
# Wisconsin                  169
# Wyoming                     21

# %%
# Give me a list of unique postal code
l=[]
unique_postal = df['Postal Code'].unique()

# %%
for i in unique_postal:
    l.append(i)
    
l
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
#  2664,
#  15122,
#  76148,
#  5439,
#  5403,
#  37664,
#  37918,
#  37086,
#  37087,
#  80525,
#  80817,
#  60452,
#  76131,
#  98059,
#  99352,
#  37804,
#  70802,
#  4092,
#  7024,
#  76240,
#  98158,
#  78415,
#  94122,
#  4011,
#  4240,
#  2474,
#  2540,
#  1580,
#  3038,
#  60505,
#  84043,
#  84321,
#  66212,
#  48138,
#  85335,
#  74006,
#  75217,
#  77536,
#  90660,
#  13501,
#  11580,
#  63114,
#  84044,
#  84047,
#  84107,
#  60453,
#  2021,
#  2766,
#  7101,
#  28227,
#  60302,
#  60462,
#  50208,
#  80027,
#  66203,
#  81503,
#  80634,
#  37922,
#  38109,
#  55423,
#  55901,
#  55113,
#  80126,
#  80232,
#  17331,
#  33772,
#  87505,
#  12208,
#  44106,
#  43229,
#  78589,
#  86001,
#  85234,
#  85301,
#  30297,
#  28204,
#  6824,
#  6111,
#  6226,
#  7109,
#  66614,
#  67212,
#  80538,
#  80233,
#  80134,
#  6830,
#  6770,
#  6855,
#  4073,
#  1069,
#  2725,
#  21234,
#  21128,
#  21208,
#  20854,
#  98115,
#  91945,
#  94404,
#  60130,
#  1007,
#  7111,
#  8052,
#  21133,
#  60510,
#  3045,
#  7410,
#  97045,
#  97206,
#  44221,
#  6478,
#  33181,
#  4101,
#  3246,
#  3101,
#  7010,
#  2878,
#  33132,
#  13601,
#  85338,
#  86401,
#  19406,
#  93727,
#  4072,
#  7628,
#  7071,
#  2816,
#  2910,
#  2886,
#  94601,
#  2149,
#  1840,
#  48234,
#  37814,
#  62223,
#  61008,
#  61701,
#  60440,
#  19026,
#  68025,
#  68801,
#  68847,
#  68502,
#  48509,
#  63105,
#  13021,
#  13905,
#  28001,
#  45406,
#  43015,
#  95240,
#  90805,
#  4901,
#  8360,
#  78666,
#  7026,
#  93405,
#  94403,
#  2358,
#  7201,
#  7032,
#  7666,
#  68104,
#  89701,
#  94583,
#  92704,
#  6010,
#  6108,
#  4330,
#  1462,
#  2370,
#  7047,
#  7480,
#  61801,
#  68701,
#  56301,
#  94024,
#  93635,
#  95032,
#  90266,
#  1923,
#  2457,
#  3054,
#  8332,
#  90069,
#  92683,
#  90604,
#  2019,
#  1915,
#  2341,
#  7506,
#  8601,
#  30318,
#  1845,
#  39180,
#  11704,
#  11795,
#  60543,
#  95020,
#  4106,
#  2062,
#  7042,
#  10154,
#  24281,
#  37130,
#  84404,
#  84057,
#  55416,
#  46041,
#  42104,
#  41011,
#  95336,
#  4038,
#  2148,
#  8753,
#  76067,
#  11226,
#  97756,
#  85204,
#  85737,
#  84062,
#  64064,
#  63043,
#  22025,
#  60061,
#  93101,
#  95051,
#  26501,
#  88201,
#  78155,
#  75090,
#  90008,
#  68046,
#  84604,
#  60067,
#  60068,
#  60087,
#  60185,
#  75081,
#  60187,
#  60090,
#  39701,
#  89015,
#  61554,
#  61604,
#  91767,
#  6415,
#  4210,
#  2032,
#  1801,
#  3301,
#  8021,
#  7031,
#  7054,
#  60091,
#  60517,
#  46016,
#  47401,
#  46032,
#  47201,
#  21136,
#  81001,
#  90045,
#  14224,
#  10605,
#  10701,
#  97301,
#  97477,
#  97224,
#  81007,
#  48195,
#  5701,
#  43952,
#  20852,
#  20602,
#  55106,
#  55378,
#  95062,
#  93454,
#  98119,
#  60544,
#  62301,
#  55379,
#  60089,
#  89115,
#  91730,
#  2116,
#  1540,
#  77373,
#  37211,
#  75203,
#  52501,
#  64133,
#  63301,
#  64506,
#  98387,
#  99207,
#  98408,
#  77478,
#  63116,
#  63376,
#  80229,
#  80030,
#  46307,
#  46312,
#  98105,
#  90041,
#  90405,
#  95404,
#  95070,
#  6040,
#  6460,
#  6850,
#  6702,
#  1520,
#  2152,
#  7067,
#  2840,
#  48841,
#  89031,
#  89041,
#  41042,
#  6614,
#  1803,
#  1420,
#  1089,
#  2190,
#  3053,
#  3079,
#  7003,
#  7016,
#  7039,
#  8232,
#  7901,
#  85345,
#  85023,
#  60423,
#  40324,
#  86301,
#  86314,
#  97062,
#  61201,
#  98661,
#  14215,
#  61107,
#  97068,
#  18103,
#  16602,
#  72143,
#  92054,
#  6033,
#  6484,
#  6437,
#  92691,
#  95351,
#  6512,
#  7001,
#  73064,
#  27502,
#  84067,
#  29915,
#  84106,
#  32168,
#  37830,
#  42420,
#  85254,
#  8046,
#  99362,
#  37167,
#  37174,
#  79605,
#  75002,
#  79109,
#  71854,
#  80033,
#  21222,
#  6511,
#  8002,
#  91745,
#  93117,
#  6114,
#  2210,
#  1450,
#  1060,
#  3839,
#  92544,
#  92345,
#  6405,
#  6810,
#  6492,
#  75503,
#  77590,
#  46514,
#  55126,
#  89502,
#  66202,
#  11575,
#  85635,
#  93422,
#  20746,
#  76017,
#  78745,
#  77520,
#  77705,
#  76021,
#  89431,
#  20024,
#  83616,
#  76201,
#  33430,
#  10039,
#  1887,
#  7652,
#  42240,
#  26003,
#  78521,
#  77803,
#  76028,
#  96003,
#  92374,
#  1463,
#  7008,
#  8857,
#  7050,
#  7501,
#  90278,
#  6776,
#  2127,
#  1605,
#  7002,
#  2914,
#  90049,
#  75482,
#  75067,
#  19901,
#  19711,
#  94061,
#  60610,
#  6105,
#  2108,
#  3842,
#  92503,
#  95677,
#  2339,
#  1841,
#  7079,
#  91761,
#  1718,
#  1701,
#  1040,
#  2151,
#  7650,
#  93030,
#  3431,
#  7601,
#  7450,
#  11720,
#  60459,
#  7712,
#  72022,
#  28806,
#  27217,
#  27511,
#  66762,
#  55125,
#  15221,
#  11722,
#  14225,
#  11725,
#  27514,
#  28205,
#  28027,
#  27707,
#  43017,
#  15102,
#  95695,
#  95991,
#  92399,
#  90004,
#  6473,
#  2109,
#  7030,
#  85351,
#  85374,
#  3060,
#  2864,
#  11727,
#  10573,
#  60409,
#  62901,
#  18018,
#  60441,
#  60174,
#  60193,
#  60076,
#  11729,
#  11746,
#  8816,
#  8817,
#  7646,
#  65721,
#  10282,
#  18040,
#  75220,
#  77566,
#  75146,
#  78041,
#  77573,
#  80004,
#  85281,
#  85705,
#  85364,
#  72714,
#  72015,
#  92592,
#  95661,
#  75116,
#  78852,
#  78539,
#  2118,
#  79907,
#  76039,
#  75234,
#  60188,
#  75056,
#  77381,
#  75701,
#  77901,
#  76706,
#  75165,
#  76086,
#  6611,
#  1821,
#  1056,
#  1075,
#  7801,
#  90640,
#  1876,
#  7086,
#  3801,
#  7407,
#  8226,
#  7070,
#  19805,
#  32701,
#  2040,
#  10280,
#  27237,
#  84660,
#  84663,
#  35756,
#  92646,
#  90301,
#  6050,
#  6790,
#  20016,
#  34142,
#  1108,
#  1776,
#  7843,
#  2920,
#  32712,
#  46806,
#  46404,
#  46530,
#  97420,
#  19013,
#  2112,
#  1906,
#  2451,
#  7052,
#  2861,
#  19140,
#  98801,
#  75028,
#  76106,
#  75007,
#  75104,
#  78613,
#  36830,
#  35020,
#  78641,
#  10009,
#  75057,
#  60110,
#  61821,
#  77530,
#  76031,
#  80013,
#  80303,
#  40422,
#  80020,
#  80104,
#  80906,
#  73521,
#  33433,
#  33437,
#  34210,
#  91941,
#  1930,
#  8401,
#  7097,
#  46142,
#  46324,
#  47591,
#  19134,
#  15241,
#  6320,
#  47274,
#  1749,
#  2153,
#  33180,
#  75601,
#  84074,
#  98902,
#  25314,
#  82604,
#  84084,
#  84120,
#  60623,
#  11554,
#  90058,
#  80022,
#  80219,
#  77840,
#  2478,
#  1453,
#  2744,
#  8302,
#  8028,
#  7940,
#  62234,
#  10170,
#  17201,
#  77546,
#  33511,
#  33063,
#  33055,
#  78596,
#  76308,
#  52761,
#  48101,
#  32707,
#  79424,
#  75901,
#  76063,
#  75098,
#  95207,
#  6408,
#  2703,
#  1832,
#  22304,
#  46342,
#  46203,
#  94025,
#  94086,
#  91360,
#  1027,
#  1867,
#  8863,
#  60653,
#  48104,
#  49017,
#  48708,
#  84003,
#  92553,
#  95037,
#  2113,
#  47130,
#  46901,
#  47905,
#  28031,
#  44112,
#  80112,
#  21146,
#  20901,
#  44035,
#  44117,
#  65807,
#  63130,
#  63135,
#  16509,
#  17112,
#  96150,
#  6795,
#  2638,
#  8901,
#  97801,
#  29687,
#  46226,
#  46952,
#  46410,
#  68601,
#  84010,
#  84015,
#  43081,
#  44145,
#  44691,
#  82001,
#  82716,
#  33134,
#  53110,
#  60016,
#  60516,
#  46360,
#  10045,
#  94044,
#  32137,
#  59901,
#  14901,
#  33065,
#  60478,
#  46544,
#  47302,
#  47150,
#  62205,
#  6488,
#  6710,
#  1545,
#  2072,
#  55305,
#  35211,
#  35601,
#  27288,
#  92262,
#  63385,
#  92253,
#  78363,
#  33314,
#  32114,
#  46060,
#  46368,
#  47374,
#  39530,
#  39056,
#  38701,
#  39503,
#  22003,
#  22204,
#  24060,
#  78501,
#  75150,
#  33441,
#  32720,
#  60123,
#  45385,
#  28314,
#  28307,
#  6607,
#  77571,
#  63044,
#  44094,
#  44511,
#  25705,
#  82070,
#  68901,
#  20601,
#  11598,
#  11010,
#  11520,
#  95823,
#  93905,
#  2445,
#  1748,
#  45324,
#  46322,
#  97601,
#  17602,
#  46375,
#  11542,
#  10528,
#  37743,
#  74012,
#  77095,
#  39401,
#  38637,
#  39212,
#  92404,
#  94070,
#  6901,
#  11714,
#  60098,
#  27203,
#  98072,
#  90503,
#  15131,
#  33403,
#  33445,
#  22015,
#  22901,
#  23320,
#  67114,
#  25801,
#  45014,
#  45840,
#  60611,
#  77301,
#  60007,
#  20190,
#  72701,
#  72903,
#  71901,
#  19057,
#  39301,
#  44118,
#  19464,
#  30062,
#  30907,
#  30265,
#  49534,
#  27529,
#  35473,
#  72401,
#  72209,
#  92037,
#  43026,
#  45424,
#  44240,
#  45429,
#  83843,
#  88310,
#  20012,
#  11550,
#  28052,
#  27534,
#  27405,
#  27834,
#  75034,
#  30305,
#  73034,
#  73703,
#  73505,
#  73110,
#  90036,
#  79701,
#  95376,
#  1607,
#  32725,
#  34698,
#  63141,
#  60126,
#  60201,
#  61032,
#  32780,
#  46614,
#  47802,
#  46383,
#  47906,
#  50010,
#  92672,
#  92105,
#  1945,
#  30188,
#  59102,
#  61401,
#  60137,
#  94110,
#  50021,
#  52722,
#  63119,
#  26101,
#  36330,
#  90032,
#  38654,
#  39208,
#  48187,
#  49236,
#  48126,
#  48127,
#  33178,
#  11801,
#  52601,
#  50613,
#  52402,
#  15146,
#  38671,
#  1810,
#  2334,
#  1469,
#  43230,
#  1886,
#  11741,
#  35630,
#  92008,
#  6443,
#  2110,
#  1826,
#  2035,
#  2169,
#  1550,
#  1570,
#  7080,
#  7090,
#  2808,
#  87105,
#  94306,
#  22193,
#  24541,
#  ...]

# %%
# which customer segement is more profitalble find it out
df7=profitable_cust = df[["Customer Segment","Profit"]]

# %%
df7
# Out:
#      Customer Segment       Profit
# 0           Corporate     1.320000
# 1           Corporate     4.560000
# 2           Corporate   -47.640000
# 3           Corporate   -30.510000
# 4           Corporate   998.202300
# ...               ...          ...
# 9421         Consumer   137.860000
# 9422         Consumer   -39.070000
# 9423         Consumer -1225.029097
# 9424         Consumer   349.485000
# 9425         Consumer    78.062400
#
# [9426 rows x 2 columns]

# %%
df7.groupby("Customer Segment").sum()
# Out:
#                          Profit
# Customer Segment
# Consumer          206559.625349
# Corporate         505538.627783
# Home Office       283869.553809
# Small Business    316474.592482

# %%
#Try to find out 10 top product with highest  
margins = pd.DataFrame(df[["Product Base Margin","Product Name"]])

# %%
df9 = margins.groupby("Product Name").count()

# %%
df9
# Out:
#                                                     Product Base Margin
# Product Name
# "While you Were Out" Message Book, One Form per...                    6
# #10 Self-Seal White Envelopes                                         5
# #10 White Business Envelopes,4 1/8 x 9 1/2                           14
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                              18
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes                          9
# ...                                                                 ...
# i500plus                                                              2
# i600                                                                  3
# iDEN i550                                                             2
# iDEN i95                                                              4
# iDENi80s                                                              5
#
# [1263 rows x 1 columns]

# %%
max(df9["Product Base Margin"])
# Out:
# 27

# %%
asc= df9.sort_values(by='Product Base Margin',ascending=False)

# %%
asc.head(10)
# Out:
#                                                     Product Base Margin
# Product Name
# Global High-Back Leather Tilter, Burgundy                            27
# Bevis 36 x 72 Conference Tables                                      26
# Master Giant Foot® Doorstop, Safety Yellow                           24
# BoxOffice By Design Rectangular and Half-Moon M...                   24
# Wilson Jones Hanging View Binder, White, 1"                          23
# Fiskars® Softgrip Scissors                                           22
# Office Star - Mid Back Dual function Ergonomic ...                   22
# 80 Minute CD-R Spindle, 100/Pack - Staples                           22
# StarTAC 7760                                                         22
# Peel & Seel® Recycled Catalog Envelopes, Brown                       22
